# %%
pip install ultralytics roboflow --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
from roboflow import Roboflow

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="hxbapQhMhDYbZD7pyeqW")
project = rf.workspace("dsp-act-8").project("class-detection-2gujs")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

os.system("pip uninstall ultralytics -y")
os.system("pip install ultralytics==8.0.20")
# Out:
# 1

# %%
from ultralytics import YOLO

# Load the nano model (very lightweight)
model = YOLO("yolov8n.pt")

# Train the model
model.train(
    data=r"C:\Users\Ramirez Andrewnicko\Documents\GitHub\dspCPE4A2526\dspPython\ACT 8\class-detection-1\data.yaml",
    epochs=20,
    imgsz=416,          # Smaller image size saves RAM
    batch=8,            # Lower batch for low RAM
    plots=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.202 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.201  Python-3.13.7 torch-2.8.0+cpu CPU (Intel Core i3-N305)
# ...

# %%
model = YOLO("runs/detect/train11/weights/best.pt")

# %%
image_path = "download (4).jpg"
results = model(image_path, conf=.1) 
results[0].show()
# Out:
# image 1/1 c:\Users\Ramirez Andrewnicko\Documents\GitHub\dspCPE4A2526\dspPython\ACT 8\download (4).jpg: 288x416 3 glasss, 488.6ms
# Speed: 83.9ms preprocess, 488.6ms inference, 33.7ms postprocess per image at shape (1, 3, 288, 416)
