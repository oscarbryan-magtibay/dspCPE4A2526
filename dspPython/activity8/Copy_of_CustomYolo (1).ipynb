# %%
# !pip install ultralytics roboflow --quiet

# %%
from ultralytics import YOLO
from roboflow import Roboflow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
rf = Roboflow(api_key="AODSzesVAbUIuxDmHPhI")
project = rf.workspace("dspjastillana").project("my-first-project-ztqzv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-1 in yolov8:: 100%|██████████| 41/41 [00:00<00:00, 4916.56it/s]

# %%
# !yolo task=detect mode=train model=yolov8l.pt data={dataset.location}/data.yaml epochs=20 imgsz=640 batch=16 plots=True
# Out:
# Ultralytics 8.3.214 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
