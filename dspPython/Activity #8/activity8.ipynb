# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (8.3.220)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.9.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (0.24.0)
# Requirement already satisfied: psutil in c:\users\acer\appdata\roaming\python\python313\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (1.34.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\roaming\python\python313\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: polars-runtime-32==1.34.0 in c:\users\acer\appdata\local\programs\python\python313\lib\site-packages (from polars->ultralytics) (1.34.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt

# %%
model = YOLO("best.pt")

# %%
img = cv2.imread("mouse1.jpg")
print("Image loaded:", img is not None)
# Out:
# Image loaded: True

# %%
# Path to your test image (change this to your own image path)
image_path = "mouse1.jpg"

# Run detection
results = model("mouse1.jpg", conf=0.5)  # confidence threshold 50%

# results[0] contains detections for the first (and only) image
results[0].show()   # OpenCV popup (if supported)
# Out:
# image 1/1 c:\Users\acer\OneDrive\Documents\GitHub\dspCPE4A2526\dspPython\Activity #8\mouse1.jpg: 448x640 1 Mouse, 753.9ms
# Speed: 4.8ms preprocess, 753.9ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Path to your image
image_path = "mouse1.jpg"

# Run detection
results = model(image_path, conf=0.25)

# Get detection results for first (and only) image
boxes = results[0].boxes
names = model.names  # class names (COCO dataset: 'person' is class 0)

# Filter only "person" detections
person_boxes = []
for box in boxes:
    cls = int(box.cls[0])
    if names[cls] == "person":
        person_boxes.append(box)

print(f"Detected {len(person_boxes)} person(s).")
# Out:
# image 1/1 c:\Users\acer\OneDrive\Documents\GitHub\dspCPE4A2526\dspPython\Activity #8\mouse1.jpg: 448x640 1 Mouse, 753.2ms
# Speed: 5.0ms preprocess, 753.2ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Detected 0 person(s).

# %%
img = cv2.imread(image_path)

# Draw only person detections
for box in boxes:
    cls = int(box.cls[0])
    if names[cls] == "person":
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
        conf = float(box.conf[0])
        label = f"Person {conf:.2f}"

        cv2.rectangle(img, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
        cv2.putText(img, label, (int(x1), int(y1) - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

# Show in OpenCV window
cv2.imshow("Person Detection", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
