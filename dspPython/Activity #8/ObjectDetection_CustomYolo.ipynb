# %%
# !pip install ultralytics roboflow --quiet

# %%
from ultralytics import YOLO
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="lSKLmJcSiXiWpXq7PIGG")
project = rf.workspace("activity8").project("activity8-98ywf")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data={dataset.location}/data.yaml epochs=19 imgsz=640 batch=17 plots=True
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
