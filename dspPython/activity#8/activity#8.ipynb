# %%
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# !pip install ultralytics roboflow --quiet
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ca3LyIZvtDC3VALE0tVh")
project = rf.workspace("dspojalesjp-c5bqo").project("objectdetection-aui7m")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="C:\Users\Jhon Paul Ojales\OneDrive\文档\Github_jp\dspCPE4A2526\dspPython\activity#8\ObjectDetection-1\data.yaml" epochs=30 imgsz=640 batch=16 plots=True
# Out:
# Ultralytics 8.3.203  Python-3.13.1 torch-2.8.0+cpu CPU (13th Gen Intel Core i5-13500HX)
# ...

# %%
import cv2
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt

# %%
model = YOLO(r"C:\Users\Jhon Paul Ojales\OneDrive\文档\Github_jp\dspCPE4A2526\dspPython\activity#8\runs\detect\train9\weights\best5.pt")

# %%
image_path = r"C:\Users\Jhon Paul Ojales\OneDrive\文档\Github_jp\dspCPE4A2526\dspPython\activity#8\images\ballpen9.jpg"
results = model(image_path, conf=0.5)
results[0].show()   # shows result in a window
# Out:
# image 1/1 C:\Users\Jhon Paul Ojales\OneDrive\\Github_jp\dspCPE4A2526\dspPython\activity#8\images\ballpen9.jpg: 640x640 (no detections), 72.8ms
# Speed: 4.9ms preprocess, 72.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
