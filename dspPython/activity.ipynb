# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(-5,10)
x = (2.0 ** n)
print("n =", n)
print("x =", x)
# Out:
# n = [-3.14 -2.14 -1.14 -0.14  0.86  1.86  2.86]
# x = [0.11343989 0.22687979 0.45375958 0.90751916 1.81503831 3.63007662
#  7.26015324]

# %%
plt.stem(n, x)
plt.title('Sequence x[n] = 2^n')
plt.xlabel('n (sample index)')
plt.ylabel('x[n]')
plt.grid(True)
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.show()

# %%
n = np.arange(-3.14, 3.14, 0.01)
x = np.sin(n)

plt.stem(n, x)
plt.title('Sinusoidal Wave')
plt.ylabel('Y')
plt.xlabel('X')
plt.grid(True)
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)

# %%
n = np.arange(1, 50, 1)
x = np.log(n)

plt.stem(n, x)
plt.title('Natural Logarithmic Function')
plt.ylabel('Y')
plt.xlabel('X')
plt.grid(True)
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)

# %% [markdown]
# plt.stem(n, x)
# plt.title('Sequence x[n] = 2^n')
# plt.xlabel('n (sample index)')
# plt.ylabel('x[n]')
# plt.grid(True)
# plt.axhline(0, color='black', lw=0.5)
# plt.axvline(0, color='black', lw=0.5)
# plt.show()
