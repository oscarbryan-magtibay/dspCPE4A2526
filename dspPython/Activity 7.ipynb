# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(-10, 11)
x = np.zeros(n.size)


x[(n >= -2) & (n <= 4)] = 3      
x[n == -5] = -2                  
x[n == 7] = 1.5                  

plt.stem(n, x, 'r', basefmt='k')  
plt.title('Original Sequence (x[n])')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(-10,11)
x = np.zeros(n.size)


x[(n >= -5) & (n <= -1)] = 4      
x[n == 2] = -3                  
x[n == 8] = 2.5                 

plt.stem(n, x[::-1], 'g', basefmt='k')
plt.title('Time Reverse (x[n])')
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(-10,11)
x = np.zeros(n.size)


x[(n >= -3) & (n <= 2)] = 3    
x[n == -8] = -2                
x[n == 6] = 2.5                


xf = x[::-1]
xe = (x + xf) / 2

plt.stem(n, xe, 'm', basefmt='k')
plt.title('Even (x[-n])')
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(-10,11)
x = np.zeros(n.size)


x[(n >= -6) & (n <= -2)] = 1.5  
x[n == 0] = 3                    
x[n == 7] = -2                   


xf = x[::-1]
xo = (x - xf) / 2

plt.stem(n, xo, 'c', basefmt='k')
plt.title('Odd (x_o[n])')
plt.grid(True, alpha=0.3)
plt.show()
